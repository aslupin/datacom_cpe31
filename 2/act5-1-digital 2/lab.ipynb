# %%
import urllib
from sigproc import Signal,start_notebook
start_notebook()

urllib.request.urlretrieve("https://www.cpe.ku.ac.th/~cpj/204325/q5-1/q5-1-59.wav","q5-1-59.wav")
s = Signal(wav_file="q5-1-59.wav")
s.plot_time()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1002">Loading BokehJS ...</span>
#     </div>
# Notebook session ready.
#   <div class="bk-root" id="0e63da5e-832b-41d7-95fb-7282d1884ba0" data-root-id="1003"></div>

# %%
import urllib
from sigproc import Signal,start_notebook
start_notebook()

urllib.request.urlretrieve("https://www.cpe.ku.ac.th/~cpj/204325/q5-2/q5-2-59.wav","q5-2-59.wav")
s = Signal(wav_file="q5-2-59.wav")
s.plot_time()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1001">Loading BokehJS ...</span>
#     </div>
# Notebook session ready.
#   <div class="bk-root" id="2d7a455d-f55e-48a0-95e1-860296be1644" data-root-id="1002"></div>
